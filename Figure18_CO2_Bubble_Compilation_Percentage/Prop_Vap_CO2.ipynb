# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import Thermobar as pt

# %%
Allison=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Allison_et_al_2021')
Wieser=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Wieser_et_al_2021')
Lerner=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Lerner_et_2021')
Moore_Kil=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Moore_2015_Kil')
Moore_Seg=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Moore_2015_Seg')
Moore_Fueg=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Moore_2015_Fueg')
Moore_2018=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Moore_2018')
Moore_2021=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Moore_2021')
Aster=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Aster_2016')
Devitre=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Devitre_et_al_2023_fogo')
Hanyu=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Hanyu_2020')
# Mironov=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Hanyu_2020') No Data Yet
Wong=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Wong_2023')

Hernandez=pd.read_excel('Compiled_Glass_CO2_VB_Studies.xlsx', sheet_name='Hernandez_2021')

# %%
import matplotlib.patches as patches
# Dimensions for review
#fig, (ax0) = plt.subplots(1, 1, figsize=(9, 4.3), sharey=True)
# Dimensions for grant
fig, (ax0) = plt.subplots(1, 1, figsize=(8, 5), sharey=True)
hotspot=0
##### Hotspot
rect1 = patches.Rectangle((np.min(Moore_Kil['Perc_CO2_Bubble']*100),-0.4),
(np.max(Moore_Kil['Perc_CO2_Bubble']*100)-np.min(Moore_Kil['Perc_CO2_Bubble']*100))
    ,0.8,linewidth=1,edgecolor='None',facecolor='cyan', alpha=0.2, zorder=0)
ax0.add_patch(rect1)
ax0.plot( Moore_Kil['Perc_CO2_Bubble']*100,Moore_Kil['Perc_CO2_Bubble']*0, 'ok', mfc='cyan')

#####
rect2 = patches.Rectangle((np.min(Wieser['Perc_CO2_Bubble']),-0.4+1),
(np.max(Wieser['Perc_CO2_Bubble'])-np.min(Wieser['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='cyan', alpha=0.2, zorder=0)
ax0.add_patch(rect2)
ax0.plot( Wieser['Perc_CO2_Bubble'],Wieser['Perc_CO2_Bubble']*0+1, 'ok', mfc='cyan', zorder=100)

##########
rect3 = patches.Rectangle((np.min(Lerner['Perc_CO2_Bubble']),-0.4+2),
(np.max(Lerner['Perc_CO2_Bubble'])-np.min(Lerner['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='cyan', alpha=0.2, zorder=0)
ax0.add_patch(rect3)
ax0.plot( Lerner['Perc_CO2_Bubble'], Lerner['Perc_CO2_Bubble']*0+2, 'ok', mfc='cyan', alpha=0.7)

########
rect4 = patches.Rectangle((np.min(Moore_2021['Perc_CO2_Bubble']),-0.4+3.5),
(np.max(Moore_2021['Perc_CO2_Bubble'])-np.min(Moore_2021['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='cornflowerblue', alpha=0.2, zorder=0)
ax0.add_patch(rect4)
ax0.plot( Moore_2021['Perc_CO2_Bubble'], Moore_2021['Perc_CO2_Bubble']*0+3.5, 'ok', mfc='cornflowerblue',
         zorder=100)

#####
rect5 = patches.Rectangle((np.min(Hanyu['Perc_CO2_Bubble']),-0.4+4.5),
(np.max(Hanyu['Perc_CO2_Bubble'])-np.min(Hanyu['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='blue', alpha=0.2, zorder=0)
ax0.add_patch(rect5)
ax0.plot( Hanyu['Perc_CO2_Bubble'], Hanyu['Perc_CO2_Bubble']*0+4.5, 'ok', mfc='blue', alpha=0.7)


rect5b = patches.Rectangle((np.min(Devitre['Perc_CO2_Bubble']),-0.4+5.5),
(np.max(Devitre['Perc_CO2_Bubble'])-np.min(Devitre['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='blue', alpha=0.2, zorder=0)
ax0.add_patch(rect5b)
ax0.plot( Devitre['Perc_CO2_Bubble'], Devitre['Perc_CO2_Bubble']*0+5.5, 'ok', mfc='navy', alpha=0.7)


mono=7.5
### Monogenetic ---------------------------------
rect6 = patches.Rectangle((np.min(Allison['Perc_CO2_Bubble']),-0.4+mono),
(np.max(Allison['Perc_CO2_Bubble'])-np.min(Allison['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='grey', alpha=0.2, zorder=0)
ax0.add_patch(rect6)
ax0.plot( Allison['Perc_CO2_Bubble'],Allison['Perc_CO2_Bubble']*0+mono, 'dk', mfc='grey')

rect7 = patches.Rectangle((np.min(Hernandez['Perc_CO2_Bubble']),-0.4+mono+1+0.2),
(np.max(Hernandez['Perc_CO2_Bubble'])-np.min(Hernandez['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='black', alpha=0.2, zorder=0)
ax0.add_patch(rect7)
ax0.plot( Hernandez['Fraction of CO2 in bubble']*100,Hernandez['Perc_CO2_Bubble']*0+mono+1+0.2,
         'dk', mfc='black')

rect7b = patches.Rectangle((np.min(Wong['Perc_CO2_Bubble']),-0.4+mono+1.8+0.2),
(np.max(Wong['Perc_CO2_Bubble'])-np.min(Wong['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='black', alpha=0.2, zorder=0)
ax0.add_patch(rect7b)
ax0.plot(Wong['Perc_CO2_Bubble'],Wong['Perc_CO2_Bubble']*0+mono+1.8+0.2,
         'dk', mfc='white')



## ARC MAGMAS -------------------------------------------------------------
arc=mono+2+1+1+1.5

###
rect8 = patches.Rectangle((np.min(Moore_Seg['Perc_CO2_Bubble']*100),-0.4+arc-1),
(np.max(Moore_Seg['Perc_CO2_Bubble']*100)-np.min(Moore_Seg['Perc_CO2_Bubble']*100))
    ,0.8,linewidth=1,edgecolor='None',facecolor='red', alpha=0.2, zorder=0)
ax0.add_patch(rect8)
ax0.plot( Moore_Seg['Perc_CO2_Bubble']*100, Moore_Seg['Perc_CO2_Bubble']*0+arc-1, 
         '^k', mfc='red')

###
rect9 = patches.Rectangle((np.min(Moore_Fueg['Perc_CO2_Bubble']*100),-0.4+arc),
(np.max(Moore_Fueg['Perc_CO2_Bubble']*100)-np.min(Moore_Fueg['Perc_CO2_Bubble']*100))
    ,0.8,linewidth=1,edgecolor='None',facecolor='darkred', alpha=0.2, zorder=0)
ax0.add_patch(rect9)
ax0.plot( Moore_Fueg['Perc_CO2_Bubble']*100,Moore_Fueg['Perc_CO2_Bubble']*0+arc, 
         '^k', mfc='darkred')

###
rect9 = patches.Rectangle((np.min(Aster['Perc_CO2_Bubble']),-0.4+arc+1),
(np.max(Aster['Perc_CO2_Bubble'])-np.min(Aster['Perc_CO2_Bubble']))
    ,0.8,linewidth=1,edgecolor='None',facecolor='coral', alpha=0.2, zorder=0)
ax0.add_patch(rect9)
ax0.plot( Aster['Perc_CO2_Bubble'],Aster['Perc_CO2_Bubble']*0+arc+1, 
         '^k', mfc='coral')

###
rect10 = patches.Rectangle((np.min(Moore_2018['Perc_CO2_Bubble']),-0.4+arc+2),
(np.max(Moore_2018['Perc_CO2_Bubble'])-np.min(Moore_2018['Perc_CO2_Bubble']*100))
    ,0.8,linewidth=1,edgecolor='None',facecolor='magenta', alpha=0.2, zorder=0)
ax0.add_patch(rect10)
ax0.plot( Moore_2018['Perc_CO2_Bubble'],Moore_2018['Perc_CO2_Bubble']*0+arc+2, '^k', mfc='magenta')
#plt.grid(color = 'k', linestyle = '-', linewidth = 1, alpha = 0.1, axis='y')
#ax0.set_yticks([0, 1, 2, 3.5, 4.5, 6, 7, 9, 10, 11, 12])
ax0.set_ylim([-2, 16])
ax0.set_yticklabels([])
ax0.set_xlim([-5, 150])
plt.gca().invert_yaxis()
fig.savefig('CO2_Bubbles2.png', dpi=200)

# %%
np.min(Moore_2021['Perc_CO2_Bubble'])

plt.plot( Moore_Seg['Perc_CO2_Bubble']*100, Moore_Seg['Perc_CO2_Bubble']*0+arc, 'sk', mfc='red')
