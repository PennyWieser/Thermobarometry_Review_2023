# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import pyMELTScalc as M
import Thermobar as pt
import pickle

#sys.path.append(r'G:\My Drive\2022\GitHub\pyMELTScalc\MELTS')

import time
import random
from tqdm.notebook import tqdm, trange

import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12

# %%
Data = pd.read_excel('FullResults_Final.xlsx')

# %%
with open('P_result_v120_full.obj', 'rb') as f:
    P_results = pickle.load(f)
    
with open('P_result_v102_full.obj', 'rb') as f:
    P_results_v102 = pickle.load(f)

# %%
P_bar = np.linspace(100,7500,38)/1000

Data['P_kbar_calc'] = np.zeros(len(Data['SiO2_Liq']))*np.nan
Data['P_kbar_calc_min'] = np.zeros(len(Data['SiO2_Liq']))*np.nan

Data['P_kbar_calc_v102'] = np.zeros(len(Data['SiO2_Liq']))*np.nan
Data['P_kbar_calc_v102_min'] = np.zeros(len(Data['SiO2_Liq']))*np.nan

for i in P_results:
    Loc = np.where(P_results[i]['Res_abc'][0,0,:] == np.nanmin(P_results[i]['Res_abc']))
    if Loc is not None:
        Data['P_kbar_calc'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
        Data['P_kbar_calc_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])
        
for i in P_results_v102:
    Loc = np.where(P_results_v102[i]['Res_abc'][0,0,:] == np.nanmin(P_results_v102[i]['Res_abc']))
    if Loc is not None:
        Data['P_kbar_calc_v102'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
        Data['P_kbar_calc_v102_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['P_kbar_calc'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['P_kbar_calc_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:10: RuntimeWarning: All-NaN slice encountered
#   Loc = np.where(P_results[i]['Res_abc'][0,0,:] == np.nanmin(P_results[i]['Res_abc']))
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:12: RuntimeWarning: Mean of empty slice
#   Data['P_kbar_calc'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:13: RuntimeWarning: All-NaN slice encountered
#   Data['P_kbar_calc_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['P_kbar_calc_v102'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['P_kbar_calc_v102_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:16: RuntimeWarning: All-NaN slice encountered
#   Loc = np.where(P_results_v102[i]['Res_abc'][0,0,:] == np.nanmin(P_results_v102[i]['Res_abc']))
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:18: RuntimeWarning: Mean of empty slice
#   Data['P_kbar_calc_v102'].loc[int(i)] = np.nanmean(P_bar[Loc[0]])
# C:\Users\penny\AppData\Local\Temp\ipykernel_27016\2555367453.py:19: RuntimeWarning: All-NaN slice encountered
#   Data['P_kbar_calc_v102_min'].loc[int(i)] = np.nanmin(P_results_v102[i]['Res_abc'])

# %%
T_cut = 20

f, a = plt.subplots(1,2, figsize=(11, 4.5))
plt.subplots_adjust(hspace = 0.0, wspace = 0.25)

a[0].plot([0,5],[0,5], '-k')
s = a[0].scatter(Data['P_kbar'], Data['P_bar_calc_v120']/1000, 70, c = Data['T_residual_v120'],
                 edgecolor = 'k', cmap = "hot_r", vmin = 0, vmax = 150, marker = 's')
a[0].plot(Data['P_kbar'][Data['T_residual_v120'] < T_cut], 
          0.001*Data['P_bar_calc_v120'][Data['T_residual_v120'] < T_cut], 'sw', 
          markersize = 8, markeredgecolor = 'k', mew = 2)
a[0].set_xlabel('Experimental P (kbar)')
a[0].set_ylabel('Calculated P v.1.2.0 (kbar)')
#f.colorbar(s, ax=a[0], label='$\Delta$T ($^{o}$C)')

a[1].plot([0,5],[0,5], '-k')
a[1].scatter(Data['P_kbar'], Data['P_bar_calc_v102']/1000, 70, c = Data['T_residual_v102'], 
             edgecolor = 'k', cmap = "hot_r", vmin = 0, vmax = 150, marker = 'o')
a[1].plot(Data['P_kbar'][Data['T_residual_v102'] < T_cut], 
          0.001*Data['P_bar_calc_v102'][Data['T_residual_v102'] < T_cut], 
          'ow', markersize = 10, markeredgecolor = 'k', mew = 2)
a[1].set_xlabel('Experimental P (kbar)')
a[1].set_ylabel('Calculated P v.1.0.2 (kbar)')

plt.savefig('AB.png', dpi = 200)

# %%
import Thermobar as pt
pt.calculate_R2(Data['SiO2_Liq'], Data['P_kbar']-Data['P_bar_calc_v102'], xy=False)
# Out:
# {'R2': '0.55',
#  'RMSE': '3826.95',
#  'RMSE_num': 3826.95,
#  'P_val': '0.000',
#  'Median': '-1826.60',
#  'Mean': '-2929.03',
#  'Int': array([17663.92987301]),
#  'Grad': array([-323.45688808])}

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
x='SiO2_Liq'
ax1.plot(Data[x], Data['P_kbar']-Data['P_bar_calc_v102'], 'ok')
ax2.plot(Data[x], Data['P_kbar']-Data['P_bar_calc_v120'], 'ok')

# %%
Harmon_SiO2=np.array([71.54, 63.50, 68.20, 61.80, 60.7, 62.39, 63.73, 64.49])
Harmon_PCalc=np.array([300, np.nan, 195, 105, 10, 120, 125, 165])
Harmon_PExp=np.array([400, 500, 44, 100.8, 0.1, 100, 100, 150])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
cutoff2=100
Data_Filterv102=Data.loc[Data['T_residual_v102']<50]
Data_Filterv120=Data.loc[Data['T_residual_v120']<50]

Corrv102=pt.calculate_R2(Data['SiO2_Liq'], Data['P_kbar']-Data['P_bar_calc_v102']/1000)
Corrv120=pt.calculate_R2(Data['SiO2_Liq'], Data['P_kbar']-Data['P_bar_calc_v120']/1000)

x='SiO2_Liq'
ax1.plot(Data_Filterv102[x], Data_Filterv102['P_kbar']-Data_Filterv102['P_bar_calc_v102']/1000, 'ok', mfc='r')
ax1.plot(Corrv102['x_pred'], Corrv102['y_pred'], '-r')
ax1.plot(Data_Filterv120[x], Data_Filterv120['P_kbar']-Data_Filterv120['P_bar_calc_v120']/1000, 'sk', mfc='cyan')
ax1.plot(Corrv120['x_pred'], Corrv120['y_pred'], '-c')

ax1.plot(Harmon_SiO2, (Harmon_PCalc-Harmon_PExp)/100, '*k', ms=10)

# %%
import Thermobar as pt
pt.calculate_R2(Data['SiO2_Liq'], Data['P_kbar']-Data['P_bar_calc_v102']/1000, xy=False)
# Out:
# {'R2': '0.85',
#  'RMSE': '65.23',
#  'RMSE_num': 65.23,
#  'P_val': '0.000',
#  'Median': '-63.62',
#  'Mean': '-64.72',
#  'Int': array([26.04594305]),
#  'Grad': array([-0.43013183])}

# %%
Data.loc[Data[x]>65]
# Out:
#     Unnamed: 0                                  Citation  \
# 9            9                     Mandler2013_notinLEPR
# 10          10                     Mandler2013_notinLEPR
# 17          17                      Almeev2013_notinLEPR
# 20          20                      Almeev2013_notinLEPR
# 21          21                      Cadoux2014_notinLEPR
# 22          22                      Cadoux2014_notinLEPR
# 23          23                    Nakatani2022_notinLEPR
# 24          24                    Nakatani2022_notinLEPR
# 25          25                    Nakatani2022_notinLEPR
# 26          26                    Nakatani2022_notinLEPR
# 27          27                    Nakatani2022_notinLEPR
# 28          28                    Nakatani2022_notinLEPR
# 29          29                    Nakatani2022_notinLEPR
# 30          30                    Nakatani2022_notinLEPR
# 31          31                    Nakatani2022_notinLEPR
# 32          32         Prouteau, G., Scaillet, B. (2003)
# 33          33  Moore, G., and Carmichael, I.S.E. (1998)
#
#                          Experiment   SiO2_Liq  TiO2_Liq  Al2O3_Liq  FeOt_Liq  \
# 9                     Mandle272Ja-1  69.600000  0.610000  16.000000  2.980000
# 10                   Mandle272Ja-2b  70.400000  0.470000  15.700000  2.970000
# 17                       AlmeevAB62  66.590000  1.090000  15.660000  4.240000
# 20                       AlmeevAB54  65.310000  1.050000  17.000000  3.710000
# 21  CadouxMinoan_FMQ_850C_2kbar_0.9  73.048058  0.305118  14.305929  2.146957
# 22      CadouxCR_FMQ_900C_4kbar_0.6  69.432023  0.663541  15.372383  3.289096
# 23                    NakataHG-629N  71.493423  0.343083  11.616000  1.334667
# 24                    NakataHG-629L  70.622543  0.325818  11.568636  1.383636
# 25                    NakataHG-604N  72.849808  0.384200  11.122000  1.495500
# 26                    NakataHG-604L  70.818001  0.337556  11.123445  1.584778
# 27                    NakataHG-596N  70.349403  0.351773  11.880271  1.592727
# 28                    NakataHG-596L  69.009415  0.332364  11.603045  1.540045
# 29                    NakataHG-607N  70.666794  0.350067  11.901333  1.469333
# 30                    NakataHG-595N  69.194885  0.436889  12.175668  1.738556
# 31                    NakataHG-595L  67.642998  0.433800  12.056400  1.701700
# 32                           PIN98s  71.650000  0.240000  15.260000  2.080000
# 33                         PEM12-11  68.200000  1.030000  13.700000  3.160000
#
#      MnO_Liq   MgO_Liq   CaO_Liq  ...  P_bar_calc_PlagOpx_v120  \
# 9   0.130000  0.720000  2.040000  ...              7500.000000
# 10  0.100000  0.560000  1.680000  ...              7500.000000
# 17  0.130000  1.980000  4.450000  ...              3967.336683
# 20  0.090000  2.310000  4.980000  ...              5622.613065
# 21  0.144842  0.433089  1.845428  ...              5500.000000
# 22  0.119477  0.609974  2.394199  ...              7500.000000
# 23  0.079083  0.391250  2.121417  ...              6500.000000
# 24  0.073818  0.399273  2.186636  ...              6300.000000
# 25  0.077100  0.356500  1.919200  ...              6700.000000
# 26  0.080111  0.373000  2.101111  ...              6700.000000
# 27  0.083773  0.418727  2.262546  ...              6500.000000
# 28  0.078045  0.426682  2.270773  ...              6300.000000
# 29  0.079133  0.412267  2.247467  ...              6100.000000
# 30  0.094667  0.542111  2.546222  ...              6900.000000
# 31  0.086200  0.572500  2.597500  ...              6700.000000
# 32  0.000000  1.000000  2.990000  ...              7500.000000
# 33  0.000000  1.200000  3.200000  ...              4599.497487
#
#     T_residual_PlagOpx_v120  P_bar_calc_v102  P_bar_calc_PlagOpx_v102  \
# 9                 23.829589              NaN              6644.723618
# 10                32.160699              NaN              7500.000000
# 17                 3.881636      5005.527638              1998.492462
# 20                 2.419371      1762.311558              2687.939698
# 21                17.084378              NaN              1700.000000
# 22                25.806708              NaN              7300.000000
# 23                27.431143      6203.517588              3500.000000
# 24                26.169678      5797.487437              2300.000000
# 25                18.837713              NaN              2900.000000
# 26                19.048063      6648.743719              4700.000000
# 27                23.329440      6595.477387              3500.000000
# 28                21.118122      5811.557789              1700.000000
# 29                29.946209      5985.427136              2110.050251
# 30                15.310184      5713.065327              1900.000000
# 31                11.853236      4834.673367              1900.000000
# 32                39.645531              NaN                      NaN
# 33                 7.609714      3669.849246              3707.035176
#
#     T_residual_v102  T_residual_PlagOpx_v102  P_kbar_calc  P_kbar_calc_min  \
# 9               NaN                 2.166400          NaN              NaN
# 10              NaN                 4.330116          NaN              NaN
# 17        42.951067                 3.450506          5.9              NaN
# 20        18.977834                13.325694          NaN              NaN
# 21              NaN                 9.849866          NaN              NaN
# 22              NaN                 1.925202          NaN            190.0
# 23        25.631759                 9.408190          NaN              NaN
# 24        26.345731                 7.999427          NaN              NaN
# 25              NaN                 4.866477          7.1             95.0
# 26        30.041250                17.260759          7.5            109.0
# 27        33.357143                13.942535          0.1              5.0
# 28        31.450174                 3.003096          0.1            114.0
# 29        27.331706                 7.464199          7.4             89.0
# 30        40.513862                 9.117022          NaN              NaN
# 31        39.085905                13.800979          NaN              NaN
# 32              NaN                      NaN          NaN              NaN
# 33        27.127203                24.140872          5.7             21.0
#
#     P_kbar_calc_v102  P_kbar_calc_v102_min
# 9                NaN                   NaN
# 10               NaN                   NaN
# 17               NaN                   NaN
# 20               NaN                   NaN
# 21               NaN                   NaN
# 22               0.9                 190.0
# 23               NaN                   NaN
# 24               NaN                   NaN
# 25               5.3                  95.0
# 26               0.1                 109.0
# 27               5.1                   5.0
# 28               7.3                 114.0
# 29               7.1                  89.0
# 30               NaN                   NaN
# 31               NaN                   NaN
# 32               NaN                   NaN
# 33               0.9                  21.0
#
# [17 rows x 33 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
x='H2O_Liq'
ax1.plot(Data[x], Data['P_kbar']-Data['P_bar_calc_v102'], 'ok')
ax2.plot(Data[x], Data['P_kbar']-Data['P_bar_calc_v120'], 'ok')

# %%
EK=Data['Citation']=='Erdman_Koepke2016_notinLEPR' #.unique()

# %%
plt.plot(Data['P_kbar'][EK], 
          Data['P_kbar_calc'][EK], 'ok')

# %%
sample='33'

print(Data['Citation'].loc[int(sample)])
print(Data['Experiment'].loc[int(sample)])

figure_mosaic="""
AC
BC
"""
fig,axes=plt.subplot_mosaic(mosaic=figure_mosaic, figsize=(10, 4.5), sharex=True)
plt.subplots_adjust(hspace = 0.0, wspace = 0.25)

axes['A'].plot(P_bar, P_results_v102[sample]['a_sat'][0,0,:], '-', linewidth = 2, color = [0.5,0.5,0.5])
axes['A'].plot(P_bar, P_results_v102[sample]['b_sat'][0,0,:], '-g', linewidth = 2)
axes['A'].plot(P_bar, P_results_v102[sample]['c_sat'][0,0,:], '-', linewidth = 2, color = 'salmon')
axes['A'].plot(Data['P_kbar'].loc[int(sample)], Data['T_K'].loc[int(sample)]-273.15, '*k', 
               mfc = 'yellow', ms = 20)
axes['A'].set_ylabel('T ($^{o}$C)')

axes['B'].plot(P_bar, P_results[sample]['a_sat'][0,0,:], '--', linewidth = 2, color = [0.5,0.5,0.5])
axes['B'].plot(P_bar, P_results[sample]['b_sat'][0,0,:], '--g', linewidth = 2)
axes['B'].plot(P_bar, P_results[sample]['c_sat'][0,0,:], '--', linewidth = 2, color = 'salmon')
axes['B'].plot(Data['P_kbar'].loc[int(sample)], Data['T_K'].loc[int(sample)]-273.15, '*k', 
               mfc = 'yellow', ms = 20)
axes['B'].set_ylabel('T ($^{o}$C)')
axes['B'].set_xlabel('P (kbar)')


axes['C'].plot([Data['P_kbar'].loc[int(sample)],Data['P_kbar'].loc[int(sample)]],
              [0,200], '-', alpha = 0.6, lw = 8, c = 'yellow')
axes['C'].plot(P_bar, P_results_v102[sample]['Res_abc'][0,0,:], '-k')
axes['C'].plot(P_bar, P_results[sample]['Res_abc'][0,0,:], '--k')
axes['C'].set_ylabel('$\Delta$T ($^{o}$C)')
axes['C'].set_xlabel('P (kbar)')
axes['C'].set_ylim([0,200])

plt.savefig('CDE.pdf', dpi = 300)
# Out:
# Moore, G., and Carmichael, I.S.E. (1998)
# PEM12-19
