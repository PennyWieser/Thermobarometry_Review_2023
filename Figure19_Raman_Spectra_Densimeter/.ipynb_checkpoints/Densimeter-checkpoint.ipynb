# %%
import numpy as np
import pandas as pd
import Thermobar as pt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import warnings as w
pd.options.display.max_columns = None

# %%
plt.style.use("seaborn-colorblind")
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =12
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 6 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 14 # Overall title
plt.rcParams["axes.labelsize"] = 14 # Axes labels

# %%
split=np.linspace(102.5, 106)
# Kawakami et al. 2003. 
Kaw2003=-0.03238697*split**3+ 10.08428*split**2 -  1046.189*split + 36163.67
Kaw2003_Filt=Kaw2003[(Kaw2003>=0.1) & (Kaw2003<1.21)]
Split_Kaw2003=split[(Kaw2003>=0.1) & (Kaw2003<1.21)]

# Yamamoto and Kagi 2007
YK2007=-0.01917*(split-100)**3 + 0.1984* (split-100)**2 -0.2410*(split-100)-0.341
# Lamdadrid et al. 2017
L2017=-36.42055+0.354812*split
# Fall et al. 2011

F2011=-0.0303145513*split**3 + 9.432834797*split**2 - 977.9384933*split + 33780.38242
# Rosso and Bodnar, 1995


# Wang et al. 2011
W2011=47513.64243 - 1374.824414*split + 13.25586152*split**2 - 0.04258891551*split**3
# DeVitre et al. 2021
LowT_D2021_CCMR=-38.26455+0.3722442*split
HighT_D2021_CCMR=-40.22688 + 0.3913402*split
HighT_D2021=-38.62718 + 0.3760427*split
LowT_D2021=-38.34631 + 0.3732578*split
# Wang et al. 2019

# %%
density_example=-38.34631 + 0.3732578*103.197
density_example
# Out:
# 0.17277518659999913

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(5*0.8,4*0.8), sharey=True)
ax1.plot(split, Kaw2003, '-c')
ax1.plot(split, YK2007, '-b')
ax1.plot(split, L2017, '-', color='grey')
ax1.plot(split, F2011, '-', color='green')
ax1.plot(split, W2011, '-', color='magenta')
ax1.plot(split, LowT_D2021, '-', color='k')
ax1.plot(split, HighT_D2021, ':', color='k')


ax1.plot([103.197, 103.197], [0, 0.4], '-', color='r')
ax1.set_xlim([102.5, 103.3])
ax1.set_ylim([0, 0.3])

fig.savefig('DensimeterComparison.png', dpi=200, bbox_inches='tight')

# %%
split2=103.197
Kaw20032=-0.03238697*split2**3+ 10.08428*split2**2 -  1046.189*split2 + 36163.67

# %%
Kaw20032
# Out:
# 0.2930214977095602
