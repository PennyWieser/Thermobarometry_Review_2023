# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import Thermobar as pt

# %%
out=pt.import_excel('Hammer_Ps.xlsx', sheet_name='Sheet1', suffix='_Cpx')
Cpx=out['Cpxs']
all=out['my_input']

# %%
comps=pt.calculate_clinopyroxene_components(cpx_comps=Cpx)

# %% [markdown]
# In summary, according to this assessment, the best thermometer is
# the model of Putirka et al. (2003), and the best barometer is
# the clinopyroxene-only temperature-dependent barometer
# of Putirka (2008) Eq. 32b, with input temperature calculated using the model of Putirka et al. (1996).

# %%
P=pt.calculate_cpx_only_press_temp(cpx_comps=Cpx, equationT='T_Put2008_eq32d', equationP='P_Put2008_eq32a').P_kbar_calc

# %%
sum(comps['Jd_from 0=Na, 1=Al'])
# Out:
# 0

# %%
Cpx
# Out:
#     SiO2_Cpx  TiO2_Cpx  Al2O3_Cpx  FeOt_Cpx   MnO_Cpx  MgO_Cpx  CaO_Cpx  \
# 0    47.6171   1.72339    8.61506   6.98528  0.097265  13.8444  21.1761
# 1    49.3961   1.33035    6.57291   5.83864  0.093601  14.8617  21.6922
# 2    49.8020   1.20909    6.09225   5.94828  0.078454  15.2787  21.6075
# 3    47.6931   1.85182    7.93182   7.06910  0.085835  13.8386  22.0238
# 4    47.9209   1.68254    7.65591   6.71086  0.100962  14.2857  21.4929
# ..       ...       ...        ...       ...       ...      ...      ...
# 59   45.8413   1.72287    8.40172   7.31872  0.116151  13.8393  20.8138
# 60   46.6867   1.54940    7.58226   6.81342  0.114548  14.1779  21.1375
# 61   46.2745   1.62338    7.94716   6.97432  0.095359  14.0874  20.9968
# 62   45.6866   1.96022    7.74248   7.11932  0.095283  13.6266  22.0136
# 63   46.4669   1.89343    8.51208   7.22062  0.120264  13.5564  20.1326
#
#     Na2O_Cpx   K2O_Cpx  Cr2O3_Cpx  Sample_ID_Cpx
# 0   0.683481  0.000000   0.518777              0
# ...

# %%
spongy_Ka01=(all['texture']=='spongy')&(all['xstal']=='Ka01 crystals: Ka01-26 (mickey), Ka01-18 (Gizmo)')
nonspongy_Ka01=(all['texture']=='nonspongy')&(all['xstal']=='Ka01 crystals: Ka01-26 (mickey), Ka01-18 (Gizmo)')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.set_title('Ka01 crystals')
x1=P[spongy_Ka01]
x1_sorted=np.sort(x1)
ax1.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='orange', linewidth=1, label='Spongy')

x1=P[nonspongy_Ka01]
x1_sorted=np.sort(x1)
ax1.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='blue', linewidth=1, label='nonspongy')
ax1.legend()

x1=comps['Jd'].loc[spongy_Ka01]
x1_sorted=np.sort(x1)
ax2.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='orange', linewidth=1)

x1=comps['Jd'].loc[nonspongy_Ka01]
x1_sorted=np.sort(x1)
ax2.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='blue', linewidth=1)
ax1.set_xlabel('Calc P eq32a-32d')
ax2.set_xlabel('Jd')
ax1.set_ylabel('cumulative freq')
# Out:
# Text(0, 0.5, 'cumulative freq')

# %%
spongy_KaP=(all['texture']=='spongy')&(all['xstal']=='Ka02-04 (Mr. Pink) crystals')
nonspongy_KaP=(all['texture']=='nonspongy')&(all['xstal']=='Ka02-04 (Mr. Pink) crystals')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.set_title('Mr. Pink crystals')
x1=P[spongy_KaP]
x1_sorted=np.sort(x1)
ax1.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='orange', linewidth=1, label='Spongy')

x1=P[nonspongy_KaP]
x1_sorted=np.sort(x1)
ax1.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='blue', linewidth=1, label='nonspongy')
ax1.legend()

x1=comps['Jd'].loc[spongy_KaP]
x1_sorted=np.sort(x1)
ax2.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='orange', linewidth=1)

x1=comps['Jd'].loc[nonspongy_KaP]
x1_sorted=np.sort(x1)
ax2.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='blue', linewidth=1)
ax1.set_xlabel('Calc P eq32a-32d')
ax2.set_xlabel('Jd')
ax1.set_ylabel('cumulative freq')
# Out:
# Text(0, 0.5, 'cumulative freq')

# %%
plt.plot(comps['Al2O3_Cpx'].loc[spongy_Ka01], comps['Jd'].loc[spongy_Ka01], 'ok')
plt.plot(comps['Al2O3_Cpx'].loc[nonspongy_Ka01], comps['Jd'].loc[nonspongy_Ka01], 'or')

# %%
plt.plot(comps['Jd'].loc[spongy_Ka01], comps['SiO2_Cpx'].loc[spongy_Ka01], 'ok')
plt.plot(comps['Jd'].loc[nonspongy_Ka01], comps['SiO2_Cpx'].loc[nonspongy_Ka01], 'or')

# %%
plt.plot(comps['Al2O3_Cpx'].loc[spongy_KaP], comps['Na2O_Cpx'].loc[spongy_KaP], 'ok')
plt.plot(comps['Al2O3_Cpx'].loc[nonspongy_KaP], comps['Na2O_Cpx'].loc[nonspongy_KaP], 'or')

# %%
plt.plot(comps['Al2O3_Cpx'].loc[spongy_KaP], comps['SiO2_Cpx'].loc[spongy_KaP], 'ok')
plt.plot(comps['Al2O3_Cpx'].loc[nonspongy_KaP], comps['SiO2_Cpx'].loc[nonspongy_KaP], 'or')

# %% [markdown]
# Ubide_for comparons

# %%
outU=pt.import_excel('Ubide_Data_Cpx.xlsx', sheet_name='Python', suffix='_Cpx')
CpxU=outU['Cpxs']
allU=outU['my_input']
CpxU
# Out:
#       SiO2_Cpx  TiO2_Cpx  Al2O3_Cpx  FeOt_Cpx  MnO_Cpx  MgO_Cpx  CaO_Cpx  \
# 0        50.30    1.2985       4.03      7.98   0.2678    14.07    21.79
# 1        49.61    1.3449       4.70      8.19   0.1761    13.86    21.84
# 2        49.88    1.3273       4.90      7.76   0.2016    13.95    21.95
# 3        48.70    1.3674       5.31      8.01   0.1246    13.66    21.92
# 4        49.53    1.2861       5.05      7.72   0.1185    13.83    22.23
# ...        ...       ...        ...       ...      ...      ...      ...
# 1596      0.00    0.0000       0.00      0.00   0.0000     0.00     0.00
# 1597      0.00    0.0000       0.00      0.00   0.0000     0.00     0.00
# 1598      0.00    0.0000       0.00      0.00   0.0000     0.00     0.00
# 1599      0.00    0.0000       0.00      0.00   0.0000     0.00     0.00
# 1600      0.00    0.0000       0.00      0.00   0.0000     0.00     0.00
#
#       Na2O_Cpx  K2O_Cpx  Cr2O3_Cpx  Sample_ID_Cpx
# ...

# %%
len(allU)
# Out:
# 1601

# %%
compsU=pt.calculate_clinopyroxene_components(cpx_comps=CpxU)
# Out:
# c:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)

# %%
z111=allU['Type']=='#(-111)'
z100=allU['Type']=='#(100)'
plt.plot(compsU['Al2O3_Cpx'].loc[z111], compsU['Jd'].loc[z111], 'ok')
plt.plot(compsU['Al2O3_Cpx'].loc[z100], compsU['Jd'].loc[z100], 'or')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.set_title('Mr. Pink crystals')
x1=compsU['Jd'].loc[z111]
x1_sorted=np.sort(x1)
ax1.step(np.concatenate([x1_sorted, x1_sorted[[-1]]]),
         np.arange(x1_sorted.size+1)/x1_sorted.size, color='orange', linewidth=1, label='Spongy')

ax2.set_title('Mr. Pink crystals')
x2=compsU['Jd'].loc[z100]
x2_sorted=np.sort(x2)
ax1.step(np.concatenate([x2_sorted, x2_sorted[[-1]]]),
         np.arange(x2_sorted.size+1)/x2_sorted.size, color='red', linewidth=1, label='Spongy')
