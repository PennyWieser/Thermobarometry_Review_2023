# %%
import DiadFit as pf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use("seaborn-colorblind")
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =12
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 6 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 13 # Overall title
plt.rcParams["axes.labelsize"] = 13 # Axes labels

# %%
filename='47 BL10_MI1_xscan1.txt'

# %%
df3=pf.read_witec_to_df(path=None,
                       filename='44 BL10_MI1.txt')
# Out:
# 44 BL10_MI1.txt

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(8,3), sharex=True, sharey=True)

ax1.plot(df3['X-Axis'], df3['BL10_MI1'], '-g')
fig.savefig('BL10_Center.png', dpi=200)

# %%
df2=pf.read_witec_to_df(path=None,
                       filename=filename)
# Out:
# 47 BL10_MI1_xscan1.txt

# %%
df2.head()
# Out:
#         X-Axis  BL10_MI1_xscan1(0)  BL10_MI1_xscan1(1)  BL10_MI1_xscan1(2)  \
# 0  1042.057870               948.0               956.0              1051.0
# 1  1042.624871               928.0               967.0              1055.0
# 2  1043.191812               948.0               944.0              1030.0
# 3  1043.758695               944.0               938.0              1038.0
# 4  1044.325518               943.0               971.0              1030.0
#
#    BL10_MI1_xscan1(3)  BL10_MI1_xscan1(4)  BL10_MI1_xscan1(5)  \
# 0               911.0               909.0               854.0
# 1               911.0               902.0               876.0
# 2               899.0               896.0               857.0
# 3               885.0               897.0               860.0
# 4               899.0               887.0               856.0
#
#    BL10_MI1_xscan1(6)  BL10_MI1_xscan1(7)  BL10_MI1_xscan1(8)  ...  \
# 0               779.0               772.0               760.0  ...
# ...

# %%
np.shape(df2)[0]-2
# Out:
# 1022

# %%
fig, (ax2) = plt.subplots(1, 1, figsize=(8,5), sharey=True, sharex=True)
ax2.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(0)], '-b')
ax2.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(9)], '-k')
ax2.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(4)], '-r')

y2=980
y1=770
ax1.plot([1090, 1090], [y1, y2], ':k', alpha=0.5)
# ax1.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.2)
# ax2.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.2)
fig.subplots_adjust(hspace=0)
ax2.set_ylim([720, 1000])
ax2.set_xlim([1020, 1600])
fig.savefig('BL10_RHS.png', dpi=200)

# %%
fig, (ax1, ax2, ax3, ax5) = plt.subplots(4, 1, figsize=(8,7), sharex=True, sharey=True)
ax1.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(0)], '-b')
ax2.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(4)], '-r')
#ax3.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(9)], '-k')
#ax4.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(11)], '-', color='grey')
ax3.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(17)], '-',color='grey')
ax5.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(18)], '-',color='magenta')

ax1.set_yticks([800, 900])
y2=980
y1=770
#ax1.plot([1090, 1090], [y1, y2], ':k', alpha=0.5)
# ax1.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.2)
# ax2.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.2)
fig.subplots_adjust(hspace=0)
#ax2.set_ylim([720, 1000])
ax2.set_xlim([1020, 1600])
fig.savefig('BL10_RHS.png', dpi=200)

# %%
fig, (ax1) = plt.subplots(1, figsize=(10,5), sharey=True)
i=18
ax1.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(i)], '-')

# %%
fig, (ax1) = plt.subplots(1, figsize=(10,5), sharey=True)
for i in range(0, np.shape(df2)[1]-2):
    ax1.plot(df2['X-Axis'], df2['BL10_MI1_xscan1({})'.format(i)], '-')
plt.ylim([600, 1200])
plt.xlim([1040, 1200])
# Out:
# (1040.0, 1200.0)
